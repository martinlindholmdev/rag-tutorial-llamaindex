# %%
# Run this cell first to install all required packages. Only needs to be done once.
# !pip install llama-index

# %%
import os
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader

# %%
# Set environment variable, this key you need to create at
os.environ["OPENAI_API_KEY"] = "API KEY HERE"

# %%
# Read daya from 'data' folder
documents = SimpleDirectoryReader("data").load_data()

# %%
# Create index and embed documents
index = VectorStoreIndex.from_documents(documents)

# %%
# Create query engine
query_engine = index.as_query_engine()

# %%
# Query the database
response = query_engine.query("What is the data about?")
print(response)
# Out:
# The data is about regulations and guidelines related to the handling, processing, and storage of clinical investigation information, as well as the establishment of an electronic system for clinical investigations in the European Union.
